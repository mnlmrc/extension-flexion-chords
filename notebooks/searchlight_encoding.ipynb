# %%
import os
import EFC_learningfMRI.globals as gl
import nitools as nt
from imaging_pipelines.vis import plot_surf
from matplotlib.colors import LinearSegmentedColormap, Normalize
import nibabel as nb
import numpy as np
from matplotlib.cm import ScalarMappable
import matplotlib.pyplot as plt

# %%
cmap = 'inferno'
thresh = 0.1
vmin, vmax = 0, .6
H = 'L'
glm = 3
sess = 3

gifti = nb.load(os.path.join(gl.baseDir, gl.surfDir, f'searchlight.encoding.glm{glm}.session{sess}.{H}.func.gii'))
data = nt.get_gifti_data_matrix(gifti)
data_avg = np.nanmean(data, axis=1)[:, None]

fig, ax = plt.subplots()
fig, ax = plot_surf(fig, ax, data_avg, H, col=0, vmin=vmin, vmax=vmax, thresh=thresh, cmap='inferno')

# ---- add colorbar ----
norm =Normalize(vmin=vmin, vmax=vmax)
sm = ScalarMappable(norm=norm, cmap=cmap)
cbar = fig.colorbar(sm, ax=ax, fraction=0.02, pad=0.04, orientation='horizontal')
cbar.set_label('dissimilarity (a.u.)')
cbar.ax.set_xlim(thresh, vmax)
cbar.ax.set_xticks([thresh, vmax])
cbar.outline.set_edgecolor('k')

ax.set_title(f'Chord encoding on session {sess} (left hemisphere)')

plt.show()
# Out:
# /localscratch/tmp/ipykernel_209072/2684061241.py:10: RuntimeWarning: Mean of empty slice
#   data_avg = np.nanmean(data, axis=1)[:, None]

# %%
sess = 9

gifti = nb.load(os.path.join(gl.baseDir, gl.surfDir, f'searchlight.encoding.glm{glm}.session{sess}.{H}.func.gii'))
data = nt.get_gifti_data_matrix(gifti)
data_avg = np.nanmean(data, axis=1)[:, None]

fig, ax = plt.subplots()
fig, ax = plot_surf(fig, ax, data_avg, H, col=0, vmin=vmin, vmax=vmax, thresh=thresh, cmap='inferno')

# ---- add colorbar ----
norm =Normalize(vmin=vmin, vmax=vmax)
sm = ScalarMappable(norm=norm, cmap=cmap)
cbar = fig.colorbar(sm, ax=ax, fraction=0.02, pad=0.04, orientation='horizontal')
cbar.set_label('dissimilarity (a.u.)')
cbar.ax.set_xlim(thresh, vmax)
cbar.ax.set_xticks([thresh, vmax])
cbar.outline.set_edgecolor('k')

ax.set_title(f'Chord encoding on session {sess} (left hemisphere)')

plt.show()
# Out:
# /localscratch/tmp/ipykernel_209072/2434645017.py:5: RuntimeWarning: Mean of empty slice
#   data_avg = np.nanmean(data, axis=1)[:, None]

# %%
sess = 23

gifti = nb.load(os.path.join(gl.baseDir, gl.surfDir, f'searchlight.encoding.glm{glm}.session{sess}.{H}.func.gii'))
data = nt.get_gifti_data_matrix(gifti)
data_avg = np.nanmean(data, axis=1)[:, None]

fig, ax = plt.subplots()
fig, ax = plot_surf(fig, ax, data_avg, H, col=0, vmin=vmin, vmax=vmax, thresh=thresh, cmap='inferno')

# ---- add colorbar ----
norm =Normalize(vmin=vmin, vmax=vmax)
sm = ScalarMappable(norm=norm, cmap=cmap)
cbar = fig.colorbar(sm, ax=ax, fraction=0.02, pad=0.04, orientation='horizontal')
cbar.set_label('dissimilarity (a.u.)')
cbar.ax.set_xlim(thresh, vmax)
cbar.ax.set_xticks([thresh, vmax])
cbar.outline.set_edgecolor('k')

ax.set_title(f'Chord encoding on session {sess} (left hemisphere)')

plt.show()
# Out:
# /localscratch/tmp/ipykernel_209072/168213198.py:5: RuntimeWarning: Mean of empty slice
#   data_avg = np.nanmean(data, axis=1)[:, None]
