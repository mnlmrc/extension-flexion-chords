# %%
import EFC_learningfMRI.globals as gl
from EFC_learningfMRI.vis import plot_im_sess
import os
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt
from imaging_pipelines.vis import plot_surf
from matplotlib.colors import LinearSegmentedColormap, Normalize
import nibabel as nb
import nitools as nt
from matplotlib.cm import ScalarMappable
import numpy as np
# Out:
# base directory found: /cifs/diedrichsen/data/Chord_exp/EFC_learningfMRI
# Atlas directory found: atlases
# figure directory found: figures/

# %%
H = 'L'
atlas = 'ROI'
rois = gl.rois[atlas]
glm = 2
stat = 'nanmean'
df = pd.read_csv(os.path.join(gl.baseDir, f'glm{glm}', 'ROI.activation.tsv'), sep='\t')
N = df.sn.nunique()
df_chord = df.groupby(['chord', 'session', 'sn', 'regionname', 'Hem', 'rep']).mean(numeric_only=True).reset_index()

# %%
fig, axs = plt.subplots(1, len(rois), sharey=True, sharex=True, figsize=(7, 2), constrained_layout=True)
plot_im_sess(fig, axs, df_chord[(df_chord.Hem==H) & (df_chord.rep==1)], rois=rois, roi_col='regionname', y=stat, hue='chord', hue_order=['trained', 'untrained'], palette=['lightcoral', 'cornflowerblue'], add_zero=True)
plot_im_sess(fig, axs, df_chord[(df_chord.Hem==H) & (df_chord.rep==2)], rois=rois, roi_col='regionname', y=stat, hue='chord', hue_order=['trained', 'untrained'], palette=['firebrick', 'darkblue'], add_zero=True)
sb.despine(ax=axs[0], trim=True)
axs[0].set_ylabel('activation (a.u.)')
axs[-1].legend([], frameon=False, loc='upper right')
fig.legend(frameon=False, loc='lower right')
axs[0].set_xlabel('session')
fig.suptitle(f'Activation relative to rest (N={N})')
plt.show()

# %%
df_rep[df_rep.session=='sess03']
# Out:
# rep      chord session   sn regionname       rep1       rep2
# 0      trained  sess03  101         M1   5.871072   5.925311
# 1      trained  sess03  101        PMd   8.070547   8.471591
# 2      trained  sess03  101        PMv   4.815454   5.755720
# 3      trained  sess03  101         S1   4.618707   4.192102
# 4      trained  sess03  101        SMA   0.294083   0.898842
# ..         ...     ...  ...        ...        ...        ...
# 379  untrained  sess03  113         S1  43.116060  35.331159
# 380  untrained  sess03  113        SMA  18.472866  15.982836
# 381  untrained  sess03  113       SPLa  39.921334  31.893748
# 382  untrained  sess03  113       SPLp  30.353018  23.558572
# 383  untrained  sess03  113         V1   0.734622   0.850292
#
# [192 rows x 6 columns]

# %%
df_rep = df_chord[df_chord.Hem==H].pivot_table(
    index=['chord', 'session', 'regionname'], columns='rep', values=stat
).reset_index().rename(columns={1: 'rep1', 2: 'rep2'})

palette, hue_order = ['red', 'blue'], ['trained', 'untrained']
sessions = sorted(df_rep.session.unique())
lims = [min(df_rep[['rep1', 'rep2']].min()), max(df_rep[['rep1', 'rep2']].max())]

fig, axs = plt.subplots(1, len(sessions), sharex=True, sharey=True, figsize=(3 * len(sessions), 3), constrained_layout=True)

for ax, session in zip(axs, sessions):
    sb.scatterplot(data=df_rep[df_rep.session == session], x='rep1', y='rep2', hue='chord',
                   hue_order=hue_order, palette=palette, style='regionname', ax=ax, legend=(ax is axs[-1]))
    ax.plot(lims, lims, 'k--', lw=1, zorder=0)
    ax.set_title(session)
    ax.set_xlabel('rep 1 activation (a.u.)')
    sb.despine(ax=ax, trim=True)

axs[0].set_ylabel('rep 2 activation (a.u.)')
axs[-1].legend(frameon=False, bbox_to_anchor=(1.02, 1), loc='upper left')
plt.show()

# %%
cold_colors = [(0, 0, 0), (0, 0, 1), (0, 1, 1), (1, 1, 1)]  # RGB tuples
cold = LinearSegmentedColormap.from_list('cold_custom', cold_colors, N=128)
hot = plt.cm.hot(np.linspace(0, 1, 128))
cold_vals = cold(np.linspace(1, 0, 128))  # reversed
combined = np.vstack((cold_vals, hot))
cmap = LinearSegmentedColormap.from_list('coldhot', combined)

thresh = 1
vmin, vmax = -10, 10

cifti = nb.load(os.path.join(gl.baseDir, gl.surfDir, f'glm{glm}.rep_suppr.session.smooth.dscalar.nii'))
gifti = nt.split_cifti_to_giftis(cifti, 'func', np.arange(cifti.shape[0]))[gl.Hem.index(H)]
rep_supr = nt.get_gifti_data_matrix(gifti).astype(float)
# data_1, data_2 = data[:, :6], data[:, 6:]
# rep_supr = data_2 - data_1
fig, axs = plt.subplots(2, 3, sharex=True, sharey=True, figsize=(8, 5), )
for gcol in range(6):
    row = 1 if gcol % 2 == 1 else 0
    col = gcol // 2
    ax = axs[row, col]
    fig, ax = plot_surf(fig, ax, rep_supr, H, cmap=cmap, col=gcol, thresh=thresh, vmin=vmin, vmax=vmax)

    if row==0:
        ax.set_title(f'session {gl.sessions[col]}', fontsize=14)
        if col==0:
            ax.text(0, .5, 'trained', transform=ax.transAxes, rotation=90, ha='right', va='center', fontsize=14)
    elif (row==1) & (col==0):
        ax.text(0, .5, 'untrained', transform=ax.transAxes, rotation=90, ha='right', va='center', fontsize=14)

    cold_half = LinearSegmentedColormap.from_list("cold_half", combined[:128])
    hot_half = LinearSegmentedColormap.from_list("hot_half", combined[128:])

neg_norm = Normalize(vmin=vmin, vmax=-thresh)
sm_neg = ScalarMappable(norm=neg_norm, cmap=cold_half)
cax_neg = fig.add_axes([0.38, 0.15, 0.1, 0.015])
cbar_neg = fig.colorbar(sm_neg, ax=ax, cax=cax_neg, pad=0.01, orientation='horizontal')
cbar_neg.set_ticks([vmin, -thresh])
fig.supxlabel('suppression (a.u.)', fontsize=10, y=.05)

pos_norm = Normalize(vmin=thresh, vmax=vmax)
sm_pos = ScalarMappable(norm=pos_norm, cmap=hot_half)
cax_pos = fig.add_axes([0.52, 0.15, 0.1, 0.015])
cbar_pos = fig.colorbar(sm_pos, ax=ax, cax=cax_pos, pad=0.01, orientation='horizontal')
cbar_pos.set_ticks([thresh, vmax])

plt.subplots_adjust(left=0, right=1, bottom=.2, top=.9, hspace=0)
#fig.savefig(os.path.join(figDir, 'repetition_suppression.surface.pdf'))
plt.show()

# %%
vmin, vmax = -5, 5
thresh = 1
cifti = nb.load(os.path.join(gl.baseDir, gl.surfDir, f'glm{glm}.rep_suppr.trained_vs_untrained.smooth.dscalar.nii'))
fig, axs = plt.subplots(1, 3, sharex=True, sharey=True, figsize=(8, 3), )
for col in range(3):
    ax = axs[col]
    fig, ax = plot_surf(fig, ax, cifti, H, cmap=cmap, col=col, thresh=thresh, vmin=vmin, vmax=vmax)

    ax.set_title(f'session {gl.sessions[col]}', fontsize=14)

    cold_half = LinearSegmentedColormap.from_list("cold_half", combined[:128])
    hot_half = LinearSegmentedColormap.from_list("hot_half", combined[128:])

neg_norm = Normalize(vmin=vmin, vmax=-thresh)
sm_neg = ScalarMappable(norm=neg_norm, cmap=cold_half)
cax_neg = fig.add_axes([0.38, 0.2, 0.1, 0.02])
cbar_neg = fig.colorbar(sm_neg, ax=ax, cax=cax_neg, pad=0.01, orientation='horizontal')
cbar_neg.set_ticks([vmin, -thresh])
fig.supxlabel('activation difference between trained and untrained (a.u.)', fontsize=10, y=.05)

pos_norm = Normalize(vmin=thresh, vmax=vmax)
sm_pos = ScalarMappable(norm=pos_norm, cmap=hot_half)
cax_pos = fig.add_axes([0.52, 0.2, 0.1, 0.02])
cbar_pos = fig.colorbar(sm_pos, ax=ax, cax=cax_pos, pad=0.01, orientation='horizontal')
cbar_pos.set_ticks([thresh, vmax])

#fig.suptitle('Trained vs. untrained activation (left hemisphere)')

plt.subplots_adjust(left=0, right=1, bottom=.1, top=.9, hspace=0)

plt.show()
