# %%
import EFC_learningfMRI.globals as gl
from EFC_learningfMRI.vis import plot_im_sess
import os
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt
# from imaging_pipelines.vis import plot_surf
# from matplotlib.colors import LinearSegmentedColormap, Normalize
# import nibabel as nb
# import nitools as nt
# from matplotlib.cm import ScalarMappable
import numpy as np

# %%
H = 'L'
atlas = 'ROI'
rois = gl.rois[atlas]
glm = 2
stat = 'nanmean'
df = pd.read_csv(os.path.join(gl.baseDir, f'glm{glm}', 'ROI.activation.tsv'), sep='\t')
N = df.sn.nunique()
df_chord = df.groupby(['chord', 'session', 'sn', 'regionname', 'Hem', 'repetition']).mean(numeric_only=True).reset_index()

# %%
fig, axs = plt.subplots(1, len(rois), sharey=True, sharex=True, figsize=(7, 2), constrained_layout=True)
plot_im_sess(fig, axs, df_chord[(df_chord.Hem==H) & (df_chord.repetition==1)], rois=rois, roi_col='regionname', y=stat, hue='chord', hue_order=['trained', 'untrained'], palette=['lightcoral', 'cornflowerblue'], add_zero=True)
plot_im_sess(fig, axs, df_chord[(df_chord.Hem==H) & (df_chord.repetition==2)], rois=rois, roi_col='regionname', y=stat, hue='chord', hue_order=['trained', 'untrained'], palette=['firebrick', 'darkblue'], add_zero=True)
sb.despine(ax=axs[0], trim=True)
axs[0].set_ylabel('activation (a.u.)')
axs[-1].legend([], frameon=False, loc='upper right')
fig.legend(frameon=False, loc='lower right', ncol=2)
axs[0].set_xlabel('session')
fig.suptitle(f'Activation relative to rest in repetition 1 and 2 (N={N})')
plt.show()

# %%
rep_suppr = pd.read_csv(os.path.join(gl.baseDir, f'glm{glm}', f'{atlas}.pc1_theta.tsv'), sep='\t')
rep_suppr = rep_suppr[rep_suppr.Hem==H]

fig, axs = plt.subplots(1, len(rois), sharey=True, sharex=True, figsize=(7, 2), constrained_layout=True)

plot_im_sess(fig, axs, rep_suppr, rois=rois, roi_col='roi', y='theta', hue='chord', hue_order=['trained', 'untrained'], palette=['red', 'blue'], estimator='mean', add_zero=np.deg2rad(45))
plot_im_sess(fig, axs, rep_suppr, rois=rois, roi_col='roi', y='theta', hue='chord', hue_order=['trained', 'untrained'], palette=['red', 'blue'], kind='strip')
sb.despine(ax=axs[0], trim=True)
axs[0].set_ylabel('theta (rad)')
axs[-1].legend([], frameon=False, loc='upper right')
fig.legend(frameon=False, loc='lower right',)
axs[0].set_xlabel('session')
fig.suptitle(f'Slope between repetition 1 and 2 (N={N})')
plt.show()

# %%
scaling = pd.read_csv(os.path.join(gl.baseDir, gl.pcmDir, f'scaling.repetition_suppression.glm{glm}.{atlas}.tsv'), sep='\t')
scaling = scaling[scaling.Hem==H]

fig, axs = plt.subplots(1, len(rois), sharey=True, sharex=True, figsize=(7, 2), constrained_layout=True)

plot_im_sess(fig, axs, scaling, rois=rois, roi_col='roi', y='residual', hue='chord', hue_order=['trained', 'untrained'], palette=['red', 'blue'], estimator='mean', add_zero=True)
plot_im_sess(fig, axs, scaling, rois=rois, roi_col='roi', y='residual', hue='chord', hue_order=['trained', 'untrained'], palette=['red', 'blue'], kind='strip', legend = False)
sb.despine(ax=axs[0], trim=True)
# axs[0].set_ylabel('theta (rad)')
axs[-1].legend([], frameon=False, loc='upper right')
fig.legend(frameon=False, loc='lower right',)
axs[0].set_xlabel('session')
# fig.suptitle(f'Slope between repetition 1 and 2 (N={N})')
plt.show()

# %%
scaling = pd.read_csv(os.path.join(gl.baseDir, gl.pcmDir, f'scaling.repetition_suppression.glm{glm}.{atlas}.tsv'), sep='\t')
scaling = scaling[scaling.Hem==H]

fig, axs = plt.subplots(1, len(rois), sharey=True, sharex=True, figsize=(7, 2), constrained_layout=True)

plot_im_sess(fig, axs, scaling, rois=rois, roi_col='roi', y='diss_ref', hue='chord', hue_order=['trained', 'untrained'], palette=['lightcoral', 'cornflowerblue'], estimator='mean', add_zero=True)
plot_im_sess(fig, axs, scaling, rois=rois, roi_col='roi', y='diss_target_observed', hue='chord', hue_order=['trained', 'untrained'], palette=['firebrick', 'darkblue'], estimator='mean', add_zero=True)
sb.despine(ax=axs[0], trim=True)
#axs[0].set_ylabel('theta (rad)')
axs[-1].legend([], frameon=False, loc='upper right')
fig.legend(frameon=False, loc='lower right', ncol=2)
axs[0].set_xlabel('session')
#fig.suptitle(f'Slope between repetition 1 and 2 (N={N})')
plt.show()

# %%
def simulate_Y(U, n_part=10, common=0.0, run_effect=0.0, noise=1.0, seed=0):
    rng = np.random.default_rng(seed)
    K, P = U.shape
    common_pat = rng.standard_normal(P)          # shared activation-from-rest

    Y, cond_vec, part_vec = [], [], []
    for run in range(n_part):
        run_pat = run_effect * rng.standard_normal(P)   # nuisance, same for all conds this run
        for c in range(K):
            signal = U[c] + common * common_pat + run_pat
            Y.append(signal + noise * rng.standard_normal(P))
            cond_vec.append(c)
            part_vec.append(run)
    return np.vstack(Y), np.array(cond_vec), np.array(part_vec)

# %%
import PcmPy as pcm
from EFC_learningfMRI.G_matrix import G_scaling

nRuns = 10
K = 16
nVox = 500

repetition_U = np.repeat([1, 2], K // 2)
repetition = np.tile(repetition_U, nRuns)

G_iid = np.eye(K)
L = np.linalg.cholesky(G_iid + 1e-10*np.eye(len(G_iid)))
U_base = L @ np.random.standard_normal((len(G_iid), nVox))

U_scale = U_base.copy()
U_scale[K // 2:] *= .5

loc = np.random.randint(nVox, size=(nVox // 10))
U_sharp = U_scale.copy()
U_sharp[K // 2:, loc] *= 5

fig, axs = plt.subplots(1, 3, sharex=True, sharey=True)

axs[0].plot(U_base[repetition_U==1].T, color='orange')
axs[0].plot(U_base[repetition_U==2].T, color='green')
axs[1].plot(U_scale[repetition_U==1].T, color='orange')
axs[1].plot(U_scale[repetition_U==2].T, color='green')
axs[2].plot(U_sharp[repetition_U==1].T, color='orange')
axs[2].plot(U_sharp[repetition_U==2].T, color='green')

plt.show()

# %%
scaling  = []
Us       = [U_base, U_scale, U_sharp]
U_labels = ['base', 'scale', 'sharp']
for U, label in zip(Us, U_labels):
    Y, cond_vec, part_vec = simulate_Y(U)
    G_ref, _ = pcm.est_G_crossval(Y[repetition==1], cond_vec[repetition==1], part_vec=part_vec[repetition==1], X=pcm.indicator(part_vec[repetition==1]))
    G_tar, _ = pcm.est_G_crossval(Y[repetition==2], cond_vec[repetition==2], part_vec=part_vec[repetition==2], X=pcm.indicator(part_vec[repetition==2]))
    scaling.append(G_scaling(G_ref, G_tar).assign(U=label))

scaling = pd.concat(scaling)

scaling
# Out:
#     act_ref  act_target     scale  diss_ref  diss_target_observed  diss_pred  \
# 0  0.937604    0.925504  0.987095  1.326998              1.309179   1.309872
# 0  0.937604    0.461525  0.492239  1.326998              0.653107   0.653199
# 0  0.937604    0.819963  0.874530  1.326998              1.162253   1.160499
#
#    residual      U
# 0 -0.000693   base
# 0 -0.000092  scale
# 0  0.001753  sharp
